# %%
pip install tensorflow-addons
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-addons (from versions: none)
# ERROR: No matching distribution found for tensorflow-addons
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
# =========================
# Enable Mixed Precision (if GPU is available)
# =========================
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("GPU detected. Enabling mixed precision training.")
    from tensorflow.keras import mixed_precision
    policy = mixed_precision.Policy('mixed_float16')
    mixed_precision.set_global_policy(policy)
else:
    print("No GPU detected. Training will run on CPU.")
# Out:
# No GPU detected. Training will run on CPU.

# %%
# =========================
# 1. Preprocessing Functions
# =========================
def load_and_preprocess_video(video_path, target_size=(256, 256), max_frames=500):
    print(f"Loading video: {video_path}")
    cap = cv2.VideoCapture(video_path)
    frames = []
    while cap.isOpened() and len(frames) < max_frames:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.resize(frame, target_size)
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = frame / 127.5 - 1.0  # Normalize to [-1, 1]
        frames.append(frame)
    cap.release()
    print(f"Loaded {len(frames)} frames from {video_path}")
    return np.array(frames)

def load_videos_from_folder_subset(folder_path, target_size=(256, 256), max_frames=500, num_videos=10):
    all_videos = sorted([f for f in os.listdir(folder_path) if f.endswith('.avi')])
    videos = all_videos[:num_videos]
    frames = []
    for video_file in videos:
        video_path = os.path.join(folder_path, video_file)
        video_frames = load_and_preprocess_video(video_path, target_size, max_frames)
        frames.append(video_frames)
    total_frames = np.concatenate(frames, axis=0) if frames else np.array([])
    print(f"Total frames loaded from folder {folder_path}: {total_frames.shape[0] if len(total_frames) > 0 else 0}")
    return total_frames

# %%
# =========================
# 2. Residual Block (Simplified)
# =========================
def residual_block(x, filters, kernel_size=3):
    shortcut = x
    x = layers.Conv2D(filters, kernel_size, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)  # Use BatchNorm instead of GroupNorm
    x = layers.LeakyReLU(negative_slope=0.2)(x)  # Updated parameter name
    x = layers.Conv2D(filters, kernel_size, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Add()([shortcut, x])
    x = layers.LeakyReLU(negative_slope=0.2)(x)  # Updated parameter name
    return x

# %%
# =========================
# 3. Simplified GAN Architectures
# =========================
class TemporalGAN:
    def __init__(self, frame_shape=(256, 256, 3), latent_dim=128):
        print("Initializing TemporalGAN...")
        self.frame_shape = frame_shape
        self.latent_dim = latent_dim

        self.generator = self.build_generator()
        self.discriminator = self.build_discriminator()

        # Use a slightly lower learning rate for discriminator to slow its convergence
        self.gen_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)
        self.disc_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.5)
        self.cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
        print("TemporalGAN initialized.")

    def build_generator(self):
        print("Building generator with residual blocks...")
        inputs = layers.Input(shape=(self.latent_dim,))
        x = layers.Dense(16 * 16 * 256, use_bias=False)(inputs)
        x = layers.BatchNormalization()(x)  # Use BatchNorm instead of GroupNorm
        x = layers.LeakyReLU(negative_slope=0.2)(x)  # Updated parameter name
        x = layers.Reshape((16, 16, 256))(x)
        
        # Upsample to 32x32
        x = layers.Conv2DTranspose(128, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.LeakyReLU(negative_slope=0.2)(x)  # Updated parameter name
        # Residual block at 32x32
        x = residual_block(x, 128)
        
        # Upsample to 64x64
        x = layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.LeakyReLU(negative_slope=0.2)(x)  # Updated parameter name
        # Residual block at 64x64
        x = residual_block(x, 64)
        
        # Upsample to 128x128
        x = layers.Conv2DTranspose(32, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.LeakyReLU(negative_slope=0.2)(x)  # Updated parameter name
        
        # Upsample to 256x256
        outputs = layers.Conv2DTranspose(3, (5, 5), strides=(2, 2), padding='same', activation='tanh')(x)
        
        model = models.Model(inputs, outputs)
        print("Generator built.")
        return model

    def build_discriminator(self):
        print("Building simplified discriminator...")
        model = models.Sequential([
            layers.InputLayer(shape=self.frame_shape),
            layers.GaussianNoise(0.1),
            layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same'),  # No SpectralNorm
            layers.LeakyReLU(negative_slope=0.2),  # Updated parameter name
            layers.Dropout(0.4),
            layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'),
            layers.LeakyReLU(negative_slope=0.2),  # Updated parameter name
            layers.Dropout(0.4),
            layers.Conv2D(256, (5, 5), strides=(2, 2), padding='same'),
            layers.LeakyReLU(negative_slope=0.2),  # Updated parameter name
            layers.Dropout(0.4),
            layers.Flatten(),
            layers.Dense(1)
        ])
        print("Discriminator built.")
        return model

    def generator_loss(self, fake_output):
        return self.cross_entropy(tf.ones_like(fake_output), fake_output)

    def discriminator_loss(self, real_output, fake_output):
        real_loss = self.cross_entropy(tf.ones_like(real_output) * 0.9, real_output)
        fake_loss = self.cross_entropy(tf.zeros_like(fake_output), fake_output)
        return real_loss + fake_loss

# %%
# =========================
# 4. Create an Optimized Data Pipeline
# =========================
def create_dataset(frames, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices(frames)
    dataset = dataset.shuffle(1000).batch(batch_size).repeat().prefetch(tf.data.AUTOTUNE)  # Add .repeat()
    return dataset

# %%
# =========================
# 5. Modified Training Function
# =========================
def train_temporal_gan_with_monitoring(frames, epochs=500, batch_size=8, latent_dim=128, output_dir="synthetic_frames_enhanced"):
    gen_losses = []
    disc_losses = []
    os.makedirs(output_dir, exist_ok=True)
    
    dataset = create_dataset(frames, batch_size)
    tgan = TemporalGAN(frame_shape=(256, 256, 3), latent_dim=latent_dim)
    
    steps_per_epoch = len(frames) // batch_size  # Calculate steps per epoch
    
    for epoch in range(epochs):
        print(f"\nEpoch {epoch+1}/{epochs}")
        batch_gen_losses = []
        batch_disc_losses = []
        
        for step, real_frames in enumerate(dataset):
            if step >= steps_per_epoch:  # Stop after one epoch
                break
            
            # Train generator twice
            for _ in range(2):
                noise = tf.random.normal([batch_size, latent_dim])
                with tf.GradientTape() as gen_tape:
                    generated_frames = tgan.generator(noise, training=True)
                    fake_output = tgan.discriminator(generated_frames, training=True)
                    gen_loss = tgan.generator_loss(fake_output)
                gradients_gen = gen_tape.gradient(gen_loss, tgan.generator.trainable_variables)
                tgan.gen_optimizer.apply_gradients(zip(gradients_gen, tgan.generator.trainable_variables))
            
            # Train discriminator once
            noise = tf.random.normal([batch_size, latent_dim])
            with tf.GradientTape() as disc_tape:
                generated_frames = tgan.generator(noise, training=True)
                real_output = tgan.discriminator(real_frames, training=True)
                fake_output = tgan.discriminator(generated_frames, training=True)
                disc_loss = tgan.discriminator_loss(real_output, fake_output)
            gradients_disc = disc_tape.gradient(disc_loss, tgan.discriminator.trainable_variables)
            tgan.disc_optimizer.apply_gradients(zip(gradients_disc, tgan.discriminator.trainable_variables))
            
            batch_gen_losses.append(gen_loss.numpy())
            batch_disc_losses.append(disc_loss.numpy())
        
        # Monitoring and saving
        avg_gen_loss = np.mean(batch_gen_losses)
        avg_disc_loss = np.mean(batch_disc_losses)
        print(f"Epoch {epoch+1}: gen_loss={avg_gen_loss:.4f}, disc_loss={avg_disc_loss:.4f}")
        
        if (epoch+1) % 10 == 0:  # Save samples every 10 epochs
            noise = tf.random.normal([4, latent_dim])  # Generate 4 samples
            generated_samples = tgan.generator(noise, training=False).numpy()
            generated_samples = (generated_samples + 1) * 127.5
            for idx, frame in enumerate(generated_samples.astype(np.uint8)):
                output_path = os.path.join(output_dir, f"epoch{epoch+1}_sample{idx}.png")
                cv2.imwrite(output_path, cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
    
    # Plot final training statistics
    plt.figure(figsize=(12, 6))
    plt.plot(gen_losses, label='Generator Loss')
    plt.plot(disc_losses, label='Discriminator Loss')
    plt.title("Training Progress")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.savefig(os.path.join(output_dir, "training_curve.png"))
    plt.close()

# %%
# =========================
# 5. Modified Training Function with Loss Monitoring (edited)
# =========================
def train_temporal_gan_with_monitoring(frames, epochs=500, batch_size=8, latent_dim=128, output_dir="synthetic_frames_enhanced"):
    os.makedirs(output_dir, exist_ok=True)
    
    # Loss lists for tracking per epoch
    gen_losses = []
    disc_losses = []
    
    dataset = create_dataset(frames, batch_size)
    tgan = TemporalGAN(frame_shape=(256, 256, 3), latent_dim=latent_dim)
    
    steps_per_epoch = len(frames) // batch_size
    
    for epoch in range(epochs):
        print(f"\nEpoch {epoch+1}/{epochs}")
        batch_gen_losses = []
        batch_disc_losses = []
        
        for step, real_frames in enumerate(dataset):
            if step >= steps_per_epoch:
                break
            
            # Train generator twice
            for _ in range(2):
                noise = tf.random.normal([batch_size, latent_dim])
                with tf.GradientTape() as gen_tape:
                    generated_frames = tgan.generator(noise, training=True)
                    fake_output = tgan.discriminator(generated_frames, training=True)
                    gen_loss = tgan.generator_loss(fake_output)
                gradients_gen = gen_tape.gradient(gen_loss, tgan.generator.trainable_variables)
                tgan.gen_optimizer.apply_gradients(zip(gradients_gen, tgan.generator.trainable_variables))
            
            # Train discriminator once
            noise = tf.random.normal([batch_size, latent_dim])
            with tf.GradientTape() as disc_tape:
                generated_frames = tgan.generator(noise, training=True)
                real_output = tgan.discriminator(real_frames, training=True)
                fake_output = tgan.discriminator(generated_frames, training=True)
                disc_loss = tgan.discriminator_loss(real_output, fake_output)
            gradients_disc = disc_tape.gradient(disc_loss, tgan.discriminator.trainable_variables)
            tgan.disc_optimizer.apply_gradients(zip(gradients_disc, tgan.discriminator.trainable_variables))
            
            batch_gen_losses.append(gen_loss.numpy())
            batch_disc_losses.append(disc_loss.numpy())
        
        # Calculate average losses per epoch and store them for plotting.
        avg_gen_loss = np.mean(batch_gen_losses)
        avg_disc_loss = np.mean(batch_disc_losses)
        gen_losses.append(avg_gen_loss)
        disc_losses.append(avg_disc_loss)
        print(f"Epoch {epoch+1}: gen_loss={avg_gen_loss:.4f}, disc_loss={avg_disc_loss:.4f}")
        
        # Monitoring and saving samples every 10 epochs.
        if (epoch+1) % 10 == 0:
            noise = tf.random.normal([4, latent_dim])
            generated_samples = tgan.generator(noise, training=False).numpy()
            generated_samples = (generated_samples + 1) * 127.5  # Denormalize back to [0, 255]
            for idx, frame in enumerate(generated_samples.astype(np.uint8)):
                output_path = os.path.join(output_dir, f"epoch{epoch+1}_sample{idx}.png")
                cv2.imwrite(output_path, cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
    
    # Plot final training statistics
    plt.figure(figsize=(12, 6))
    plt.plot(gen_losses, label='Generator Loss')
    plt.plot(disc_losses, label='Discriminator Loss')
    plt.title("Training Progress")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.savefig(os.path.join(output_dir, "training_curve.png"))
    plt.close()

# %%
# =========================
# 6. Data Loading and Running Training
# =========================
# Replace with the actual root folder path that contains B
root_folder = '/Users/omvishal/Desktop/B'  # <<<--- Change this to your folder path
train_videos_folder = os.path.join(root_folder, "train", "BenchPress")
print(f"Loading training videos from: {train_videos_folder}")
train_frames = load_videos_from_folder_subset(train_videos_folder, target_size=(256, 256), max_frames=500, num_videos=10)
print(f"Total training frames loaded: {train_frames.shape[0]}")
# Out:
# Loading training videos from: /Users/omvishal/Desktop/B/train/BenchPress
# Loading video: /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g01_c01.avi
# Loaded 151 frames from /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g01_c01.avi
# Loading video: /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g01_c03.avi
# Loaded 104 frames from /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g01_c03.avi
# Loading video: /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g01_c04.avi
# Loaded 105 frames from /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g01_c04.avi
# Loading video: /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g01_c05.avi
# Loaded 88 frames from /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g01_c05.avi
# Loading video: /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g01_c06.avi
# Loaded 111 frames from /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g01_c06.avi
# Loading video: /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g02_c02.avi
# Loaded 98 frames from /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g02_c02.avi
# Loading video: /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g02_c04.avi
# Loaded 95 frames from /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g02_c04.avi
# Loading video: /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g02_c05.avi
# Loaded 73 frames from /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g02_c05.avi
# Loading video: /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g02_c06.avi
# Loaded 72 frames from /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g02_c06.avi
# Loading video: /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g03_c02.avi
# Loaded 100 frames from /Users/omvishal/Desktop/B/train/BenchPress/v_BenchPress_g03_c02.avi
# Total frames loaded from folder /Users/omvishal/Desktop/B/train/BenchPress: 997
# Total training frames loaded: 997

# %%
# Set training parameters.
epochs = 250
batch_size = 8
latent_dim = 128
output_dir = "synthetic_frames_enhanced"

# Start training.
train_temporal_gan_with_monitoring(train_frames, epochs=epochs, batch_size=batch_size, latent_dim=latent_dim, output_dir=output_dir)
# Out:
# Initializing TemporalGAN...
# Building generator with residual blocks...
# Generator built.
# Building simplified discriminator...
# Discriminator built.
# TemporalGAN initialized.
#
# Epoch 1/250
# Epoch 1: gen_loss=1.0633, disc_loss=1.1632
#
# Epoch 2/250
# Epoch 2: gen_loss=0.9949, disc_loss=1.2423
#
# Epoch 3/250
# Epoch 3: gen_loss=1.0336, disc_loss=1.1981
#
# Epoch 4/250
# Epoch 4: gen_loss=1.0921, disc_loss=1.1730
#
# Epoch 5/250
# Epoch 5: gen_loss=1.2033, disc_loss=1.1132
#
# Epoch 6/250
# Epoch 6: gen_loss=1.3057, disc_loss=1.0509
#
# Epoch 7/250
# Epoch 7: gen_loss=1.4033, disc_loss=1.0017
#
# Epoch 8/250
# Epoch 8: gen_loss=1.4966, disc_loss=0.9921
#
# Epoch 9/250
# Epoch 9: gen_loss=1.5935, disc_loss=0.9118
#
# Epoch 10/250
# Epoch 10: gen_loss=1.6455, disc_loss=0.9267
#
# Epoch 11/250
# Epoch 11: gen_loss=1.7555, disc_loss=0.8918
#
# Epoch 12/250
# Epoch 12: gen_loss=1.8419, disc_loss=0.8579
#
# Epoch 13/250
# Epoch 13: gen_loss=1.8886, disc_loss=0.8406
#
# Epoch 14/250
# Epoch 14: gen_loss=1.9999, disc_loss=0.8120
#
# Epoch 15/250
# Epoch 15: gen_loss=2.1030, disc_loss=0.7884
#
# Epoch 16/250
# Epoch 16: gen_loss=2.1577, disc_loss=0.7634
#
# Epoch 17/250
# Epoch 17: gen_loss=2.1950, disc_loss=0.7526
#
# Epoch 18/250
# Epoch 18: gen_loss=2.3632, disc_loss=0.7132
#
# Epoch 19/250
# Epoch 19: gen_loss=2.3857, disc_loss=0.7248
#
# Epoch 20/250
# Epoch 20: gen_loss=2.3857, disc_loss=0.7624
#
# Epoch 21/250
# Epoch 21: gen_loss=2.4583, disc_loss=0.7142
#
# Epoch 22/250
# Epoch 22: gen_loss=2.5149, disc_loss=0.6904
#
# Epoch 23/250
# Epoch 23: gen_loss=2.6153, disc_loss=0.7210
#
# Epoch 24/250
# Epoch 24: gen_loss=2.5844, disc_loss=0.6913
#
# Epoch 25/250
# Epoch 25: gen_loss=2.6854, disc_loss=0.6670
#
# Epoch 26/250
# Epoch 26: gen_loss=2.7552, disc_loss=0.6627
#
# Epoch 27/250
# Epoch 27: gen_loss=2.7948, disc_loss=0.6823
#
# Epoch 28/250
# Epoch 28: gen_loss=2.8553, disc_loss=0.6550
#
# Epoch 29/250
# Epoch 29: gen_loss=2.8081, disc_loss=0.6694
#
# Epoch 30/250
# Epoch 30: gen_loss=2.9006, disc_loss=0.6085
#
# Epoch 31/250
# Epoch 31: gen_loss=2.8359, disc_loss=0.6876
#
# Epoch 32/250
# Epoch 32: gen_loss=2.8775, disc_loss=0.6322
#
# Epoch 33/250
# Epoch 33: gen_loss=2.9065, disc_loss=0.6549
#
# Epoch 34/250
# Epoch 34: gen_loss=3.0335, disc_loss=0.6167
#
# Epoch 35/250
# Epoch 35: gen_loss=2.8614, disc_loss=0.6522
#
# Epoch 36/250
# Epoch 36: gen_loss=3.0329, disc_loss=0.6279
#
# Epoch 37/250
# Epoch 37: gen_loss=2.9577, disc_loss=0.6218
#
# Epoch 38/250
# Epoch 38: gen_loss=2.9325, disc_loss=0.6267
#
# Epoch 39/250
# Epoch 39: gen_loss=3.0616, disc_loss=0.6320
#
# Epoch 40/250
# Epoch 40: gen_loss=3.0583, disc_loss=0.6152
#
# Epoch 41/250
# Epoch 41: gen_loss=3.2714, disc_loss=0.5979
#
# Epoch 42/250
# Epoch 42: gen_loss=3.2178, disc_loss=0.6237
#
# Epoch 43/250
# Epoch 43: gen_loss=3.2037, disc_loss=0.6319
#
# Epoch 44/250
# Epoch 44: gen_loss=3.0985, disc_loss=0.6505
#
# Epoch 45/250
# Epoch 45: gen_loss=3.1471, disc_loss=0.5998
#
# Epoch 46/250
# Epoch 46: gen_loss=3.1934, disc_loss=0.6254
#
# Epoch 47/250
# Epoch 47: gen_loss=3.2159, disc_loss=0.6104
#
# Epoch 48/250
# Epoch 48: gen_loss=3.1332, disc_loss=0.6295
#
# Epoch 49/250
# Epoch 49: gen_loss=3.2462, disc_loss=0.6236
#
# Epoch 50/250
# Epoch 50: gen_loss=3.1287, disc_loss=0.6215
#
# Epoch 51/250
# Epoch 51: gen_loss=3.2563, disc_loss=0.6017
#
# Epoch 52/250
# Epoch 52: gen_loss=3.2615, disc_loss=0.6275
#
# Epoch 53/250
# Epoch 53: gen_loss=3.2253, disc_loss=0.6166
#
# Epoch 54/250
# Epoch 54: gen_loss=3.1902, disc_loss=0.6122
#
# Epoch 55/250
# Epoch 55: gen_loss=3.2973, disc_loss=0.6214
#
# Epoch 56/250
# Epoch 56: gen_loss=3.1873, disc_loss=0.6078
#
# Epoch 57/250
# Epoch 57: gen_loss=3.3318, disc_loss=0.5959
#
# Epoch 58/250
# Epoch 58: gen_loss=3.3789, disc_loss=0.6227
#
# Epoch 59/250
# Epoch 59: gen_loss=3.3880, disc_loss=0.5861
#
# Epoch 60/250
# Epoch 60: gen_loss=3.3658, disc_loss=0.6232
#
# Epoch 61/250
# Epoch 61: gen_loss=3.3558, disc_loss=0.6225
#
# Epoch 62/250
# Epoch 62: gen_loss=3.2251, disc_loss=0.5981
#
# Epoch 63/250
# Epoch 63: gen_loss=3.3037, disc_loss=0.5992
#
# Epoch 64/250
# Epoch 64: gen_loss=3.4286, disc_loss=0.5670
#
# Epoch 65/250
# Epoch 65: gen_loss=3.4446, disc_loss=0.6094
#
# Epoch 66/250
# Epoch 66: gen_loss=3.3111, disc_loss=0.6124
#
# Epoch 67/250
# Epoch 67: gen_loss=3.2816, disc_loss=0.6026
#
# Epoch 68/250
# Epoch 68: gen_loss=3.3573, disc_loss=0.5953
#
# Epoch 69/250
# Epoch 69: gen_loss=3.3316, disc_loss=0.5982
#
# Epoch 70/250
# Epoch 70: gen_loss=3.4206, disc_loss=0.5968
#
# Epoch 71/250
# Epoch 71: gen_loss=3.4196, disc_loss=0.6328
#
# Epoch 72/250
# Epoch 72: gen_loss=3.4231, disc_loss=0.5962
#
# Epoch 73/250
# Epoch 73: gen_loss=3.3754, disc_loss=0.5977
#
# Epoch 74/250
# Epoch 74: gen_loss=3.3726, disc_loss=0.6105
#
# Epoch 75/250
# Epoch 75: gen_loss=3.4823, disc_loss=0.5902
#
# Epoch 76/250
# Epoch 76: gen_loss=3.3550, disc_loss=0.6114
#
# Epoch 77/250
# Epoch 77: gen_loss=3.3591, disc_loss=0.5927
#
# Epoch 78/250
# Epoch 78: gen_loss=3.4092, disc_loss=0.5725
#
# Epoch 79/250
# Epoch 79: gen_loss=3.4565, disc_loss=0.5905
#
# Epoch 80/250
# Epoch 80: gen_loss=3.3217, disc_loss=0.6036
#
# Epoch 81/250
# Epoch 81: gen_loss=3.4446, disc_loss=0.6234
#
# Epoch 82/250
# Epoch 82: gen_loss=3.3204, disc_loss=0.6244
#
# Epoch 83/250
# Epoch 83: gen_loss=3.3563, disc_loss=0.6013
#
# Epoch 84/250
# Epoch 84: gen_loss=3.4484, disc_loss=0.6275
#
# Epoch 85/250
# Epoch 85: gen_loss=3.3669, disc_loss=0.5981
#
# Epoch 86/250
# Epoch 86: gen_loss=3.3962, disc_loss=0.5788
#
# Epoch 87/250
# Epoch 87: gen_loss=3.4771, disc_loss=0.5967
#
# Epoch 88/250
# Epoch 88: gen_loss=3.4573, disc_loss=0.5970
#
# Epoch 89/250
# Epoch 89: gen_loss=3.3856, disc_loss=0.5909
#
# Epoch 90/250
# Epoch 90: gen_loss=3.3966, disc_loss=0.5882
#
# Epoch 91/250
# Epoch 91: gen_loss=3.5117, disc_loss=0.6176
#
# Epoch 92/250
# Epoch 92: gen_loss=3.5655, disc_loss=0.5914
#
# Epoch 93/250
# Epoch 93: gen_loss=3.4374, disc_loss=0.6173
#
# Epoch 94/250
# Epoch 94: gen_loss=3.3883, disc_loss=0.5951
#
# Epoch 95/250
# Epoch 95: gen_loss=3.3865, disc_loss=0.6241
#
# Epoch 96/250
# Epoch 96: gen_loss=3.3276, disc_loss=0.6167
#
# Epoch 97/250
# Epoch 97: gen_loss=3.3343, disc_loss=0.5876
#
# Epoch 98/250
# Epoch 98: gen_loss=3.3756, disc_loss=0.5954
#
# Epoch 99/250
# Epoch 99: gen_loss=3.4684, disc_loss=0.6380
#
# Epoch 100/250
# Epoch 100: gen_loss=3.3119, disc_loss=0.6206
#
# Epoch 101/250
# Epoch 101: gen_loss=3.2922, disc_loss=0.5883
#
# Epoch 102/250
# Epoch 102: gen_loss=3.2872, disc_loss=0.6029
#
# Epoch 103/250
# Epoch 103: gen_loss=3.3699, disc_loss=0.5963
#
# Epoch 104/250
# Epoch 104: gen_loss=3.2972, disc_loss=0.6122
#
# Epoch 105/250
# Epoch 105: gen_loss=3.5057, disc_loss=0.5992
#
# Epoch 106/250
# Epoch 106: gen_loss=3.2970, disc_loss=0.6285
#
# Epoch 107/250
# Epoch 107: gen_loss=3.3367, disc_loss=0.6368
#
# Epoch 108/250
# Epoch 108: gen_loss=3.3521, disc_loss=0.6091
#
# Epoch 109/250
# Epoch 109: gen_loss=3.3329, disc_loss=0.6453
#
# Epoch 110/250
# Epoch 110: gen_loss=3.3234, disc_loss=0.6096
#
# Epoch 111/250
# Epoch 111: gen_loss=3.3291, disc_loss=0.6394
#
# Epoch 112/250
# Epoch 112: gen_loss=3.3355, disc_loss=0.6127
#
# Epoch 113/250
# Epoch 113: gen_loss=3.2690, disc_loss=0.6246
#
# Epoch 114/250
# Epoch 114: gen_loss=3.2702, disc_loss=0.6204
#
# Epoch 115/250
# Epoch 115: gen_loss=3.3736, disc_loss=0.6137
#
# Epoch 116/250
# Epoch 116: gen_loss=3.2898, disc_loss=0.6080
#
# Epoch 117/250
# Epoch 117: gen_loss=3.3014, disc_loss=0.6117
#
# Epoch 118/250
# Epoch 118: gen_loss=3.2109, disc_loss=0.6418
#
# Epoch 119/250
# Epoch 119: gen_loss=3.1868, disc_loss=0.6187
#
# Epoch 120/250
# Epoch 120: gen_loss=3.3098, disc_loss=0.6087
#
# Epoch 121/250
# Epoch 121: gen_loss=3.2079, disc_loss=0.6388
#
# Epoch 122/250
# Epoch 122: gen_loss=3.3649, disc_loss=0.5998
#
# Epoch 123/250
# Epoch 123: gen_loss=3.3325, disc_loss=0.5948
#
# Epoch 124/250
# Epoch 124: gen_loss=3.3981, disc_loss=0.6213
#
# Epoch 125/250
# Epoch 125: gen_loss=3.2948, disc_loss=0.6193
#
# Epoch 126/250
# Epoch 126: gen_loss=3.3087, disc_loss=0.6111
#
# Epoch 127/250
# Epoch 127: gen_loss=3.3832, disc_loss=0.6223
#
# Epoch 128/250
# Epoch 128: gen_loss=3.2787, disc_loss=0.6157
#
# Epoch 129/250
# Epoch 129: gen_loss=3.2324, disc_loss=0.6031
#
# Epoch 130/250
# Epoch 130: gen_loss=3.3364, disc_loss=0.6102
#
# Epoch 131/250
# Epoch 131: gen_loss=3.2525, disc_loss=0.6254
#
# Epoch 132/250
# Epoch 132: gen_loss=3.2935, disc_loss=0.6265
#
# Epoch 133/250
# Epoch 133: gen_loss=3.2592, disc_loss=0.6126
#
# Epoch 134/250
# Epoch 134: gen_loss=3.3696, disc_loss=0.6166
#
# Epoch 135/250
# Epoch 135: gen_loss=3.3514, disc_loss=0.6286
#
# Epoch 136/250
# Epoch 136: gen_loss=3.1979, disc_loss=0.6613
#
# Epoch 137/250
# Epoch 137: gen_loss=3.3091, disc_loss=0.6168
#
# Epoch 138/250
# Epoch 138: gen_loss=3.2609, disc_loss=0.6352
#
# Epoch 139/250
# Epoch 139: gen_loss=3.2893, disc_loss=0.5917
#
# Epoch 140/250
# Epoch 140: gen_loss=3.3229, disc_loss=0.6128
#
# Epoch 141/250
# Epoch 141: gen_loss=3.3618, disc_loss=0.6346
#
# Epoch 142/250
# Epoch 142: gen_loss=3.2959, disc_loss=0.6282
#
# Epoch 143/250
# Epoch 143: gen_loss=3.2438, disc_loss=0.6189
#
# Epoch 144/250
# Epoch 144: gen_loss=3.1984, disc_loss=0.6907
#
# Epoch 145/250
# Epoch 145: gen_loss=3.3168, disc_loss=0.6151
#
# Epoch 146/250
# Epoch 146: gen_loss=3.2294, disc_loss=0.6523
#
# Epoch 147/250
# Epoch 147: gen_loss=3.1898, disc_loss=0.6343
#
# Epoch 148/250
# Epoch 148: gen_loss=3.2277, disc_loss=0.6170
#
# Epoch 149/250
# Epoch 149: gen_loss=3.2634, disc_loss=0.6507
#
# Epoch 150/250
# Epoch 150: gen_loss=3.1302, disc_loss=0.6238
#
# Epoch 151/250
# Epoch 151: gen_loss=3.1445, disc_loss=0.6262
#
# Epoch 152/250
# Epoch 152: gen_loss=3.1338, disc_loss=0.6580
#
# Epoch 153/250
# Epoch 153: gen_loss=3.2017, disc_loss=0.6128
#
# Epoch 154/250
# Epoch 154: gen_loss=3.1079, disc_loss=0.6426
#
# Epoch 155/250
# Epoch 155: gen_loss=3.1496, disc_loss=0.6065
#
# Epoch 156/250
# Epoch 156: gen_loss=3.1261, disc_loss=0.6740
#
# Epoch 157/250
# Epoch 157: gen_loss=3.1156, disc_loss=0.6120
#
# Epoch 158/250
# Epoch 158: gen_loss=3.1199, disc_loss=0.6225
#
# Epoch 159/250
# Epoch 159: gen_loss=3.3690, disc_loss=0.6285
#
# Epoch 160/250
# Epoch 160: gen_loss=3.2195, disc_loss=0.6433
#
# Epoch 161/250
# Epoch 161: gen_loss=3.1825, disc_loss=0.6317
#
# Epoch 162/250
# Epoch 162: gen_loss=3.1712, disc_loss=0.6312
#
# Epoch 163/250
# Epoch 163: gen_loss=3.1652, disc_loss=0.6371
#
# Epoch 164/250
# Epoch 164: gen_loss=3.1533, disc_loss=0.6504
#
# Epoch 165/250
# Epoch 165: gen_loss=3.1977, disc_loss=0.6287
#
# Epoch 166/250
# Epoch 166: gen_loss=3.1365, disc_loss=0.6422
#
# Epoch 167/250
# Epoch 167: gen_loss=3.1890, disc_loss=0.6235
#
# Epoch 168/250
# Epoch 168: gen_loss=3.2086, disc_loss=0.6292
#
# Epoch 169/250
# Epoch 169: gen_loss=3.1529, disc_loss=0.6294
#
# Epoch 170/250
# Epoch 170: gen_loss=3.0860, disc_loss=0.6468
#
# Epoch 171/250
# Epoch 171: gen_loss=3.2387, disc_loss=0.6114
#
# Epoch 172/250
# Epoch 172: gen_loss=3.1672, disc_loss=0.6289
#
# Epoch 173/250
# Epoch 173: gen_loss=3.2319, disc_loss=0.6170
#
# Epoch 174/250
# Epoch 174: gen_loss=3.1810, disc_loss=0.6431
#
# Epoch 175/250
# Epoch 175: gen_loss=3.1474, disc_loss=0.6349
#
# Epoch 176/250
# Epoch 176: gen_loss=3.2351, disc_loss=0.6580
#
# Epoch 177/250
# Epoch 177: gen_loss=3.1161, disc_loss=0.6476
#
# Epoch 178/250
# Epoch 178: gen_loss=3.2441, disc_loss=0.6588
#
# Epoch 179/250
# Epoch 179: gen_loss=3.0929, disc_loss=0.6756
#
# Epoch 180/250
# Epoch 180: gen_loss=3.2188, disc_loss=0.6529
#
# Epoch 181/250
# Epoch 181: gen_loss=3.2101, disc_loss=0.6154
#
# Epoch 182/250
# Epoch 182: gen_loss=3.1928, disc_loss=0.6307
#
# Epoch 183/250
# Epoch 183: gen_loss=3.2118, disc_loss=0.6576
#
# Epoch 184/250
# Epoch 184: gen_loss=2.9647, disc_loss=0.6404
#
# Epoch 185/250
# Epoch 185: gen_loss=3.0826, disc_loss=0.6666
#
# Epoch 186/250
# Epoch 186: gen_loss=3.1384, disc_loss=0.6111
#
# Epoch 187/250
# Epoch 187: gen_loss=3.1367, disc_loss=0.6427
#
# Epoch 188/250
# Epoch 188: gen_loss=3.0924, disc_loss=0.6335
#
# Epoch 189/250
# Epoch 189: gen_loss=3.2268, disc_loss=0.6410
#
# Epoch 190/250
# Epoch 190: gen_loss=3.2350, disc_loss=0.6576
#
# Epoch 191/250
# Epoch 191: gen_loss=3.1333, disc_loss=0.6497
#
# Epoch 192/250
# Epoch 192: gen_loss=3.0150, disc_loss=0.6272
#
# Epoch 193/250
# Epoch 193: gen_loss=3.1343, disc_loss=0.6294
#
# Epoch 194/250
# Epoch 194: gen_loss=3.1658, disc_loss=0.5872
#
# Epoch 195/250
# Epoch 195: gen_loss=3.1244, disc_loss=0.6331
#
# Epoch 196/250
# Epoch 196: gen_loss=3.1937, disc_loss=0.6447
#
# Epoch 197/250
# Epoch 197: gen_loss=3.1523, disc_loss=0.6195
#
# Epoch 198/250
# Epoch 198: gen_loss=3.2191, disc_loss=0.6201
#
# Epoch 199/250
# Epoch 199: gen_loss=3.2600, disc_loss=0.5944
#
# Epoch 200/250
# Epoch 200: gen_loss=3.2463, disc_loss=0.6225
#
# Epoch 201/250
# Epoch 201: gen_loss=3.1964, disc_loss=0.6157
#
# Epoch 202/250
# Epoch 202: gen_loss=3.1210, disc_loss=0.6780
#
# Epoch 203/250
# Epoch 203: gen_loss=3.2831, disc_loss=0.6666
#
# Epoch 204/250
# Epoch 204: gen_loss=3.2638, disc_loss=0.6243
#
# Epoch 205/250
# Epoch 205: gen_loss=3.2073, disc_loss=0.6298
#
# Epoch 206/250
# Epoch 206: gen_loss=3.2466, disc_loss=0.6367
#
# Epoch 207/250
# Epoch 207: gen_loss=3.1599, disc_loss=0.6648
#
# Epoch 208/250
# Epoch 208: gen_loss=3.1924, disc_loss=0.6660
#
# Epoch 209/250
# Epoch 209: gen_loss=3.1391, disc_loss=0.6452
#
# Epoch 210/250
# Epoch 210: gen_loss=2.9655, disc_loss=0.6453
#
# Epoch 211/250
# Epoch 211: gen_loss=3.0402, disc_loss=0.6567
#
# Epoch 212/250
# Epoch 212: gen_loss=3.1786, disc_loss=0.6285
#
# Epoch 213/250
# Epoch 213: gen_loss=3.1325, disc_loss=0.6288
#
# Epoch 214/250
# Epoch 214: gen_loss=3.1375, disc_loss=0.6478
#
# Epoch 215/250
# Epoch 215: gen_loss=3.0112, disc_loss=0.6119
#
# Epoch 216/250
# Epoch 216: gen_loss=3.1227, disc_loss=0.6549
#
# Epoch 217/250
# Epoch 217: gen_loss=3.1196, disc_loss=0.6485
#
# Epoch 218/250
# Epoch 218: gen_loss=3.0822, disc_loss=0.6249
#
# Epoch 219/250
# Epoch 219: gen_loss=3.1464, disc_loss=0.6379
#
# Epoch 220/250
# Epoch 220: gen_loss=3.1531, disc_loss=0.6310
#
# Epoch 221/250
# Epoch 221: gen_loss=3.1337, disc_loss=0.6149
#
# Epoch 222/250
# Epoch 222: gen_loss=3.1217, disc_loss=0.6652
#
# Epoch 223/250
# Epoch 223: gen_loss=3.1911, disc_loss=0.6478
#
# Epoch 224/250
# Epoch 224: gen_loss=3.1543, disc_loss=0.6456
#
# Epoch 225/250
# Epoch 225: gen_loss=3.1598, disc_loss=0.6610
#
# Epoch 226/250
# Epoch 226: gen_loss=3.1000, disc_loss=0.6241
#
# Epoch 227/250
# Epoch 227: gen_loss=3.0692, disc_loss=0.6144
#
# Epoch 228/250
# Epoch 228: gen_loss=3.1495, disc_loss=0.6417
#
# Epoch 229/250
# Epoch 229: gen_loss=3.0296, disc_loss=0.6416
#
# Epoch 230/250
# Epoch 230: gen_loss=3.2141, disc_loss=0.6395
#
# Epoch 231/250
# Epoch 231: gen_loss=3.1135, disc_loss=0.6314
#
# Epoch 232/250
# Epoch 232: gen_loss=3.1730, disc_loss=0.6379
#
# Epoch 233/250
# Epoch 233: gen_loss=3.1392, disc_loss=0.6293
#
# Epoch 234/250
# Epoch 234: gen_loss=3.1696, disc_loss=0.6186
#
# Epoch 235/250
# Epoch 235: gen_loss=3.0573, disc_loss=0.6332
#
# Epoch 236/250
# Epoch 236: gen_loss=3.1557, disc_loss=0.6238
#
# Epoch 237/250
# Epoch 237: gen_loss=3.2752, disc_loss=0.6622
#
# Epoch 238/250
# Epoch 238: gen_loss=3.0727, disc_loss=0.6367
#
# Epoch 239/250
# Epoch 239: gen_loss=3.1055, disc_loss=0.6344
#
# Epoch 240/250
# Epoch 240: gen_loss=3.1181, disc_loss=0.6321
#
# Epoch 241/250
# Epoch 241: gen_loss=3.2996, disc_loss=0.6395
#
# Epoch 242/250
# Epoch 242: gen_loss=3.1788, disc_loss=0.6239
#
# Epoch 243/250
# Epoch 243: gen_loss=3.2330, disc_loss=0.6036
#
# Epoch 244/250
# Epoch 244: gen_loss=3.0792, disc_loss=0.6315
#
# Epoch 245/250
# Epoch 245: gen_loss=3.1018, disc_loss=0.6078
#
# Epoch 246/250
# Epoch 246: gen_loss=3.1949, disc_loss=0.6149
#
# Epoch 247/250
# Epoch 247: gen_loss=3.2142, disc_loss=0.6272
#
# Epoch 248/250
# Epoch 248: gen_loss=3.1288, disc_loss=0.6172
#
# Epoch 249/250
# Epoch 249: gen_loss=3.2782, disc_loss=0.6195
#
# Epoch 250/250
# Epoch 250: gen_loss=3.1791, disc_loss=0.6452

# %%
# Set training parameters.
epochs = 10
batch_size = 8
latent_dim = 128
output_dir = "synthetic_frames_test3(10epoch)"

# Start training.
train_temporal_gan_with_monitoring(train_frames, epochs=epochs, batch_size=batch_size, latent_dim=latent_dim, output_dir=output_dir)

# %% [raw]
# # Assuming you have two lists: gen_losses and disc_losses, where:
# # - gen_losses contains the generator loss values for each epoch
# # - disc_losses contains the discriminator loss values for each epoch
#
# plt.figure(figsize=(12, 6))
# plt.plot(gen_losses, label='Generator Loss', color='blue', marker='o')
# plt.plot(disc_losses, label='Discriminator Loss', color='red', marker='o')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Generator and Discriminator Loss Over Epochs')
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [raw]
# # Save the trained generator and discriminator models
# tgan.generator.save('generator_model.h5')
# tgan.discriminator.save('discriminator_model.h5')
# print("Models saved successfully.")
#
# # Generate a sequence of frames using the trained generator
# num_frames = 50  # Number of frames you want in the video
# noise = tf.random.normal([num_frames, latent_dim])
# generated_frames = tgan.generator(noise, training=False).numpy()
# # Rescale from [-1, 1] to [0, 255]
# generated_frames = ((generated_frames + 1) * 127.5).astype(np.uint8)
#
# # Use OpenCV to write these frames to a video file
# height, width, _ = generated_frames[0].shape
# video_filename = 'generated_video.avi'
# fps = 5  # Adjust frame rate as desired
#
# # Define the video writer using DIVX codec
# fourcc = cv2.VideoWriter_fourcc(*'DIVX')
# video_writer = cv2.VideoWriter(video_filename, fourcc, fps, (width, height))
#
# for frame in generated_frames:
#     # OpenCV expects BGR format, so convert if necessary
#     frame_bgr = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
#     video_writer.write(frame_bgr)
#
# video_writer.release()
# print(f"Video saved as {video_filename}")
